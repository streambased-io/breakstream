# %% [markdown]
# # Streambased Core Demo — Hot / Cold Lifecycle
#
# This walkthrough takes you through the lifecycle of data in Streambased, from kafka topic → seamless merged view → cold archive. Each step shows how the population shifts between tiers via a visualization.

# %%
import pandas as pd
import json
import subprocess
import time
import os
from IPython.display import HTML, display
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

# %%
def q(sql):
    return spark.sql(sql).toPandas()

# %%
def compose(*args, capture=False):
    host_dir = os.environ["BREAKSTREAM_HOST_DIR"]
    cmd = [
        "docker", "compose",
        "--project-directory", f"{host_dir}/environment",
        "-f", f"{host_dir}/environment/docker-compose.yaml",
    ] + list(args)
    print(">", " ".join(cmd))
    result = subprocess.run(cmd, check=True, capture_output=capture, text=True)
    if capture:
        return result.stdout

# %%
def show_distribution(table='transactions'):

    def safe_int(v):
        if v is None or pd.isna(v):
            return None
        return int(v)
    
    q(f"REFRESH TABLE isk.hotset.{table}")
    q(f"REFRESH TABLE isk.merged.{table}")
    offset_peg = safe_int(q(f"SELECT MAX(kafka_offset) as kafka_offset FROM isk.hotset.{table}").iloc[0]['kafka_offset'])
    hot_row = q(f"SELECT COUNT(*) AS cnt, MIN(kafka_offset) AS earliest, MAX(kafka_offset) AS latest FROM isk.hotset.{table} where kafka_offset <= {offset_peg}").iloc[0]
    cold_row = q(f"SELECT COUNT(*) AS cnt, MIN(kafka_offset) AS earliest, MAX(kafka_offset) AS latest FROM direct.coldset.{table} where kafka_offset <= {offset_peg}").iloc[0]
    merged_row = q(f"SELECT COUNT(*) AS cnt FROM isk.merged.{table} where kafka_offset <= {offset_peg}").iloc[0]

    hot_count = safe_int(hot_row['cnt']) or 0
    cold_count = safe_int(cold_row['cnt']) or 0
    merged_count = safe_int(merged_row['cnt']) or 0

    hot_earliest = safe_int(hot_row['earliest'])
    hot_latest = safe_int(hot_row['latest'])
    cold_earliest = safe_int(cold_row['earliest'])
    cold_latest = safe_int(cold_row['latest'])

    def fmt_offset(v):
        return f"{v:,}" if v is not None else '—'

    denom = max(merged_count, 1)
    hot_pct = round(100 * hot_count / denom)
    cold_pct = round(100 * cold_count / denom)

    total_pct = hot_pct + cold_pct
    if total_pct == 0:
        hot_bar_w = 0
        cold_bar_w = 0
        empty_bar = True
    else:
        hot_bar_w = hot_pct / total_pct * 100
        cold_bar_w = cold_pct / total_pct * 100
        empty_bar = False

    def bar_label(label, width):
        if width > 15:
            return f'<span style="color:#fff;font-size:12px;font-weight:600;pointer-events:none">{label}</span>'
        return ''

    if empty_bar:
        bar_html = '<div style="width:100%;height:32px;background:#e9ecef;border-radius:4px;"></div>'
    else:
        bar_html = f'''
        <div style="display:flex;width:100%;height:32px;border-radius:4px;overflow:hidden;">
          <div style="width:{hot_bar_w:.1f}%;background:#e63946;display:flex;align-items:center;justify-content:center;">
            {bar_label('Hot Set', hot_bar_w)}
          </div>
          <div style="width:{cold_bar_w:.1f}%;background:#4cc9f0;display:flex;align-items:center;justify-content:center;">
            {bar_label('Cold Set', cold_bar_w)}
          </div>
        </div>'''

    def svg_ring(pct, color):
        r = 40
        cx = cy = 50
        circumference = 2 * 3.14159 * r
        dash = circumference * min(pct, 100) / 100
        gap = circumference - dash
        return f'''
        <svg width="100" height="100" viewBox="0 0 100 100">
          <circle cx="{cx}" cy="{cy}" r="{r}" fill="none" stroke="#e9ecef" stroke-width="8"/>
          <circle cx="{cx}" cy="{cy}" r="{r}" fill="none" stroke="{color}" stroke-width="8"
            stroke-dasharray="{dash:.2f} {gap:.2f}"
            stroke-linecap="round"
            transform="rotate(-90 {cx} {cy})"/>
          <text x="{cx}" y="{cy}" text-anchor="middle" dominant-baseline="central"
            style="font-size:16px;font-weight:700;fill:#222;">{pct}%</text>
        </svg>'''

    html = f'''
    <div style="font-family:system-ui,sans-serif;border:1.5px solid #ff6b35;border-radius:8px;padding:16px;max-width:680px;">
      <div style="margin-bottom:8px;">
        <span style="color:#ff6b35;font-weight:700;font-size:15px;">Merged Set</span>
        <span style="color:#222;font-size:15px;margin-left:16px;">Total Rows: <strong>{merged_count:,}</strong></span>
      </div>
      {bar_html}
      <div style="display:flex;gap:16px;margin-top:16px;">
        <div style="flex:1;border:1.5px solid #e63946;border-radius:6px;padding:12px;">
          <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
            <span style="color:#e63946;font-weight:700;font-size:14px;">Hot Set</span>
            <span style="color:#999;font-size:12px;">kafka</span>
          </div>
          <div style="display:flex;justify-content:center;margin:8px 0;">
            {svg_ring(hot_pct, '#e63946')}
          </div>
          <table style="width:100%;font-size:13px;border-collapse:collapse;">
            <tr><td style="color:#555;">Total Messages</td><td style="text-align:right;font-weight:600;">{hot_count:,}</td></tr>
            <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">{fmt_offset(hot_earliest)}</td></tr>
            <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">{fmt_offset(hot_latest)}</td></tr>
          </table>
        </div>
        <div style="flex:1;border:1.5px solid #4cc9f0;border-radius:6px;padding:12px;">
          <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
            <span style="color:#4cc9f0;font-weight:700;font-size:14px;">Cold Set</span>
            <span style="color:#999;font-size:12px;">iceberg</span>
          </div>
          <div style="display:flex;justify-content:center;margin:8px 0;">
            {svg_ring(cold_pct, '#4cc9f0')}
          </div>
          <table style="width:100%;font-size:13px;border-collapse:collapse;">
            <tr><td style="color:#555;">Total Rows</td><td style="text-align:right;font-weight:600;">{cold_count:,}</td></tr>
            <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">{fmt_offset(cold_earliest)}</td></tr>
            <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">{fmt_offset(cold_latest)}</td></tr>
          </table>
        </div>
      </div>
    </div>
    '''
    display(HTML(html))

# %% [markdown]
# # PART 1: STREAMBASED COMPOSABLE VIEWS

# %% [markdown]
# ![image](images/slide1.png)

# %% [markdown]
# # What does it look like today?

# %%
show_distribution()
# Out:
#     <div style="font-family:system-ui,sans-serif;border:1.5px solid #ff6b35;border-radius:8px;padding:16px;max-width:680px;">
#       <div style="margin-bottom:8px;">
#         <span style="color:#ff6b35;font-weight:700;font-size:15px;">Merged Set</span>
#         <span style="color:#222;font-size:15px;margin-left:16px;">Total Rows: <strong>62,774</strong></span>
#       </div>
#
#         <div style="display:flex;width:100%;height:32px;border-radius:4px;overflow:hidden;">
#           <div style="width:20.0%;background:#e63946;display:flex;align-items:center;justify-content:center;">
#             <span style="color:#fff;font-size:12px;font-weight:600;pointer-events:none">Hot Set</span>
#           </div>
#           <div style="width:80.0%;background:#4cc9f0;display:flex;align-items:center;justify-content:center;">
#             <span style="color:#fff;font-size:12px;font-weight:600;pointer-events:none">Cold Set</span>
#           </div>
#         </div>
#       <div style="display:flex;gap:16px;margin-top:16px;">
#         <div style="flex:1;border:1.5px solid #e63946;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#e63946;font-weight:700;font-size:14px;">Hot Set</span>
#             <span style="color:#999;font-size:12px;">kafka</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e63946" stroke-width="8"
#             stroke-dasharray="50.27 201.06"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">20%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Messages</td><td style="text-align:right;font-weight:600;">12,774</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">50,000</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">62,773</td></tr>
#           </table>
#         </div>
#         <div style="flex:1;border:1.5px solid #4cc9f0;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#4cc9f0;font-weight:700;font-size:14px;">Cold Set</span>
#             <span style="color:#999;font-size:12px;">iceberg</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#4cc9f0" stroke-width="8"
#             stroke-dasharray="201.06 50.27"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">80%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Rows</td><td style="text-align:right;font-weight:600;">50,000</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">0</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">49,999</td></tr>
#           </table>
#         </div>
#       </div>
#     </div>

# %% [markdown]
# We have zero availability for analytics

# %%
q("select count(*) from isk.coldset.transactions")
# Out:
#    count(1)
# 0     50000

# %% [markdown]
# ![image](images/slide2.png)

# %% [markdown]
# ## Streambased closes that gap

# %%
q("select count(*) from isk.hotset.transactions")
# Out:
#    count(1)
# 0     13872

# %% [markdown]
# # How? Streambased views
#
# Streambased gives you 3 views across your data:
#
# * **hotset** — data from Kafka only
# * **coldset** — data from Iceberg only
# * **merged** — a hotset and coldset seamlessly unioned by Streambased.

# %%
q("SHOW DATABASES IN isk")
# Out:
#      namespace
# 0       hotset
# 1      coldset
# 2       merged
# 3  cdc_deletes

# %% [markdown]
# Let's list hotset tables. These correspond exactly to topics in Kafka.
#
# If new topics are added they will immediately appear here.
#
# The accounts table exists in Kafka only and has no Iceberg equivalent.

# %%
q("SHOW TABLES IN isk.hotset")
# Out:
#   namespace     tableName  isTemporary
# 0    hotset      accounts        False
# 1    hotset     customers        False
# 2    hotset  transactions        False

# %% [markdown]
# Now let's list coldset tables. These correspond exactly to tables in Iceberg.
#
# Again, if new tables are added they will immediately appear here.
#
# The branches table exists in Iceberg only and has no Kafka equivalent.

# %%
q("SHOW TABLES IN direct.coldset")
# Out:
#   namespace     tableName  isTemporary
# 0   coldset      branches        False
# 1   coldset     customers        False
# 2   coldset  transactions        False

# %% [markdown]
# Finally, let's list merged tables. This is the union of topics in Kafka and tables in Iceberg.
#
# Any that exist in both Kafka and Iceberg (e.g. transactions) are intelligently unioned by Streambased.

# %%
q("SHOW TABLES IN isk.merged")
# Out:
#   namespace     tableName  isTemporary
# 0    merged      accounts        False
# 1    merged      branches        False
# 2    merged     customers        False
# 3    merged  transactions        False

# %% [markdown]
# # Streambased Hot -> Cold Transfer

# %% [markdown]
# ![image](images/slide3.png)

# %%
q("INSERT INTO direct.coldset.transactions SELECT * FROM isk.hotset.transactions")
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# This updates the layout to:

# %%
show_distribution()
# Out:
#     <div style="font-family:system-ui,sans-serif;border:1.5px solid #ff6b35;border-radius:8px;padding:16px;max-width:680px;">
#       <div style="margin-bottom:8px;">
#         <span style="color:#ff6b35;font-weight:700;font-size:15px;">Merged Set</span>
#         <span style="color:#222;font-size:15px;margin-left:16px;">Total Rows: <strong>50,000</strong></span>
#       </div>
#
#         <div style="display:flex;width:100%;height:32px;border-radius:4px;overflow:hidden;">
#           <div style="width:50.0%;background:#e63946;display:flex;align-items:center;justify-content:center;">
#             <span style="color:#fff;font-size:12px;font-weight:600;pointer-events:none">Hot Set</span>
#           </div>
#           <div style="width:50.0%;background:#4cc9f0;display:flex;align-items:center;justify-content:center;">
#             <span style="color:#fff;font-size:12px;font-weight:600;pointer-events:none">Cold Set</span>
#           </div>
#         </div>
#       <div style="display:flex;gap:16px;margin-top:16px;">
#         <div style="flex:1;border:1.5px solid #e63946;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#e63946;font-weight:700;font-size:14px;">Hot Set</span>
#             <span style="color:#999;font-size:12px;">kafka</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e63946" stroke-width="8"
#             stroke-dasharray="251.33 0.00"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">100%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Messages</td><td style="text-align:right;font-weight:600;">50,000</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">0</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">49,999</td></tr>
#           </table>
#         </div>
#         <div style="flex:1;border:1.5px solid #4cc9f0;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#4cc9f0;font-weight:700;font-size:14px;">Cold Set</span>
#             <span style="color:#999;font-size:12px;">iceberg</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#4cc9f0" stroke-width="8"
#             stroke-dasharray="251.33 0.00"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">100%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Rows</td><td style="text-align:right;font-weight:600;">50,000</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">0</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">49,999</td></tr>
#           </table>
#         </div>
#       </div>
#     </div>

# %% [markdown]
# ![image](images/slide4.png)

# %% [markdown]
# Now Iceberg has the data but:
#
# * **It's duplicated** — 2 copies of the same data
# * **It's either messy or laggy** - ETL pipelines must choose between freshness and storage efficiency

# %% [markdown]
# Now the data rolls off Kafka retention

# %%
compose('exec', 'kafka1', 'kafka-configs', '--bootstrap-server', 'kafka1:9092', '--alter', '--topic', 'transactions', '--add-config', 'segment.ms=500')
# Out:
# > docker compose --project-directory /home/thomaskwscott/Projects/breakstream/environment -f /home/thomaskwscott/Projects/breakstream/environment/docker-compose.yaml exec kafka1 kafka-configs --bootstrap-server kafka1:9092 --alter --topic transactions --add-config segment.ms=500
# Completed updating config for topic transactions.

# %%
compose('exec', 'kafka1', 'kafka-configs', '--bootstrap-server', 'kafka1:9092', '--alter', '--topic', 'transactions', '--add-config', 'retention.ms=500')
# Out:
# > docker compose --project-directory /home/thomaskwscott/Projects/breakstream/environment -f /home/thomaskwscott/Projects/breakstream/environment/docker-compose.yaml exec kafka1 kafka-configs --bootstrap-server kafka1:9092 --alter --topic transactions --add-config retention.ms=500
# Completed updating config for topic transactions.

# %% [markdown]
# Check in AKHQ that retention has kicked in

# %%
compose('exec', 'kafka1', 'kafka-configs', '--bootstrap-server', 'kafka1:9092', '--alter', '--topic', 'transactions', '--add-config', 'retention.ms=604800000')
# Out:
# > docker compose --project-directory /home/thomaskwscott/Projects/breakstream/environment -f /home/thomaskwscott/Projects/breakstream/environment/docker-compose.yaml exec kafka1 kafka-configs --bootstrap-server kafka1:9092 --alter --topic transactions --add-config retention.ms=604800000
# Completed updating config for topic transactions.

# %%
compose('exec', 'kafka1', 'kafka-configs', '--bootstrap-server', 'kafka1:9092', '--alter', '--topic', 'transactions', '--add-config', 'segment.ms=604800000')
# Out:
# > docker compose --project-directory /home/thomaskwscott/Projects/breakstream/environment -f /home/thomaskwscott/Projects/breakstream/environment/docker-compose.yaml exec kafka1 kafka-configs --bootstrap-server kafka1:9092 --alter --topic transactions --add-config segment.ms=604800000
# Completed updating config for topic transactions.

# %%
show_distribution()
# Out:
#     <div style="font-family:system-ui,sans-serif;border:1.5px solid #ff6b35;border-radius:8px;padding:16px;max-width:680px;">
#       <div style="margin-bottom:8px;">
#         <span style="color:#ff6b35;font-weight:700;font-size:15px;">Merged Set</span>
#         <span style="color:#222;font-size:15px;margin-left:16px;">Total Rows: <strong>50,000</strong></span>
#       </div>
#
#         <div style="display:flex;width:100%;height:32px;border-radius:4px;overflow:hidden;">
#           <div style="width:0.0%;background:#e63946;display:flex;align-items:center;justify-content:center;">
#
#           </div>
#           <div style="width:100.0%;background:#4cc9f0;display:flex;align-items:center;justify-content:center;">
#             <span style="color:#fff;font-size:12px;font-weight:600;pointer-events:none">Cold Set</span>
#           </div>
#         </div>
#       <div style="display:flex;gap:16px;margin-top:16px;">
#         <div style="flex:1;border:1.5px solid #e63946;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#e63946;font-weight:700;font-size:14px;">Hot Set</span>
#             <span style="color:#999;font-size:12px;">kafka</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e63946" stroke-width="8"
#             stroke-dasharray="0.00 251.33"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">0%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Messages</td><td style="text-align:right;font-weight:600;">0</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">—</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">—</td></tr>
#           </table>
#         </div>
#         <div style="flex:1;border:1.5px solid #4cc9f0;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#4cc9f0;font-weight:700;font-size:14px;">Cold Set</span>
#             <span style="color:#999;font-size:12px;">iceberg</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#4cc9f0" stroke-width="8"
#             stroke-dasharray="251.33 0.00"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">100%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Rows</td><td style="text-align:right;font-weight:600;">50,000</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">0</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">49,999</td></tr>
#           </table>
#         </div>
#       </div>
#     </div>

# %% [markdown]
# Now we have a Kafka availability problem

# %%
compose('exec', 'schema-registry', 'kafka-avro-console-consumer', '--topic', 'transactions', '--bootstrap-server', 'kafka1:9092', '--from-beginning', '--property', 'schema.registry.url=http://schema-registry:8081', '--property', 'print.offset=true', '--max-messages', '10', '--timeout-ms', '10000')
# Out:
# > docker compose --project-directory /home/thomaskwscott/Projects/breakstream/environment -f /home/thomaskwscott/Projects/breakstream/environment/docker-compose.yaml exec schema-registry kafka-avro-console-consumer --topic transactions --bootstrap-server kafka1:9092 --from-beginning --property schema.registry.url=http://schema-registry:8081 --property print.offset=true --max-messages 10 --timeout-ms 10000
# [2026-05-21 19:26:10,872] ERROR Error processing message, terminating consumer process:  (kafka.tools.ConsoleConsumer$)
# org.apache.kafka.common.errors.TimeoutException
# Processed a total of 0 messages

# %% [markdown]
# Or do we?

# %% [markdown]
# ![image](images/slide5.png)

# %%
compose('exec', 'schema-registry', 'kafka-avro-console-consumer', '--topic', 'transactions', '--bootstrap-server', 'ksi:9192', '--from-beginning', '--property', 'schema.registry.url=http://schema-registry:8081', '--property', 'print.offset=true', '--max-messages', '10')
# Out:
# > docker compose --project-directory /home/thomaskwscott/Projects/breakstream/environment -f /home/thomaskwscott/Projects/breakstream/environment/docker-compose.yaml exec schema-registry kafka-avro-console-consumer --topic transactions --bootstrap-server ksi:9192 --from-beginning --property schema.registry.url=http://schema-registry:8081 --property print.offset=true --max-messages 10
# Offset:0	{"TransactionID":"cf754401-f354-3ef3-9a45-4092051d777e","AccountID":1090,"TransactionType":"Withdrawal","TransactionAmount":8557.01,"BranchID":116,"CustomerFlaggedFraud":false,"TransactionTime":1603452886000000}
# Offset:1	{"TransactionID":"cfbefef1-12f7-0ffc-0bd8-3e48874ae14e","AccountID":1182,"TransactionType":"Withdrawal","TransactionAmount":9513.81,"BranchID":112,"CustomerFlaggedFraud":false,"TransactionTime":1603453201540000}
# Offset:2	{"TransactionID":"5d169353-bc45-6b3c-96e6-358d9ee17e5d","AccountID":1051,"TransactionType":"Deposit","TransactionAmount":705.55,"BranchID":127,"CustomerFlaggedFraud":false,"TransactionTime":1603453517080000}
# Offset:3	{"TransactionID":"6296a49b-71cf-b32c-0345-cc67c24f4a70","AccountID":1345,"TransactionType":"Deposit","TransactionAmount":9409.88,"BranchID":126,"CustomerFlaggedFraud":false,"TransactionTime":1603453832620000}
# Offset:4	{"TransactionID":"23aa1ed0-d837-2d61-743e-e7a37b2a0f93","AccountID":1087,"TransactionType":"Deposit","TransactionAmount":8331.47,"BranchID":110,"CustomerFlaggedFraud":false,"TransactionTime":1603454148160000}
# Offset:5	{"TransactionID":"0e208cf9-779b-d6fd-eaf8-562b246d170e","AccountID":1264,"TransactionType":"Deposit","TransactionAmount":6934.48,"BranchID":113,"CustomerFlaggedFraud":false,"TransactionTime":1603454463700000}
# Offset:6	{"TransactionID":"d47a0c3a-5342-b698-da33-df75f46f6bd0","AccountID":1412,"TransactionType":"Deposit","TransactionAmount":4055.32,"BranchID":125,"CustomerFlaggedFraud":false,"TransactionTime":1603454779240000}
# Offset:7	{"TransactionID":"2f43a5c3-8e6a-6b83-1ba2-093548a84f28","AccountID":1197,"TransactionType":"Withdrawal","TransactionAmount":6733.77,"BranchID":126,"CustomerFlaggedFraud":false,"TransactionTime":1603455094780000}
# Offset:8	{"TransactionID":"31b5621e-1e1f-243c-4c31-738697dfb344","AccountID":1175,"TransactionType":"Withdrawal","TransactionAmount":4158.58,"BranchID":107,"CustomerFlaggedFraud":false,"TransactionTime":1603455410320000}
# Offset:9	{"TransactionID":"4d2b587f-1489-c585-d479-d5bc36572662","AccountID":1416,"TransactionType":"Deposit","TransactionAmount":6008.04,"BranchID":125,"CustomerFlaggedFraud":false,"TransactionTime":1603455725860000}
# Processed a total of 10 messages

# %% [markdown]
# ![image](images/slide6.png)

# %% [markdown]
# # PART 2: MIXING HOT AND COLD

# %% [markdown]
# ## Start the background traffic generator
#
# We now produce continuous events into the kafka topic. Watch the hotset fill up while the coldset stays put.

# %%
compose('up', '-d', 'shadowtraffic_background')
time.sleep(8)
# Out:
# > docker compose --project-directory /home/thomaskwscott/Projects/breakstream/environment -f /home/thomaskwscott/Projects/breakstream/environment/docker-compose.yaml up -d shadowtraffic_background
#  Container environment-zookeeper1-1  Running
#  Container environment-kafka1-1  Recreate
#  Container environment-kafka1-1  Recreated
#  Container schema-registry  Recreate
#  Container schema-registry  Recreated
#  Container environment-shadowtraffic_background-1  Creating
#  Container environment-shadowtraffic_background-1  Created
#  Container environment-kafka1-1  Starting
#  Container environment-kafka1-1  Started
#  Container schema-registry  Starting
#  Container schema-registry  Started
#  Container schema-registry  Waiting
#  Container schema-registry  Healthy
#  Container environment-shadowtraffic_background-1  Starting
#  Container environment-shadowtraffic_background-1  Started

# %%
show_distribution()
# Out:
#     <div style="font-family:system-ui,sans-serif;border:1.5px solid #ff6b35;border-radius:8px;padding:16px;max-width:680px;">
#       <div style="margin-bottom:8px;">
#         <span style="color:#ff6b35;font-weight:700;font-size:15px;">Merged Set</span>
#         <span style="color:#222;font-size:15px;margin-left:16px;">Total Rows: <strong>55,963</strong></span>
#       </div>
#
#         <div style="display:flex;width:100%;height:32px;border-radius:4px;overflow:hidden;">
#           <div style="width:11.0%;background:#e63946;display:flex;align-items:center;justify-content:center;">
#
#           </div>
#           <div style="width:89.0%;background:#4cc9f0;display:flex;align-items:center;justify-content:center;">
#             <span style="color:#fff;font-size:12px;font-weight:600;pointer-events:none">Cold Set</span>
#           </div>
#         </div>
#       <div style="display:flex;gap:16px;margin-top:16px;">
#         <div style="flex:1;border:1.5px solid #e63946;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#e63946;font-weight:700;font-size:14px;">Hot Set</span>
#             <span style="color:#999;font-size:12px;">kafka</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e63946" stroke-width="8"
#             stroke-dasharray="27.65 223.68"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">11%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Messages</td><td style="text-align:right;font-weight:600;">5,962</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">50,000</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">55,961</td></tr>
#           </table>
#         </div>
#         <div style="flex:1;border:1.5px solid #4cc9f0;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#4cc9f0;font-weight:700;font-size:14px;">Cold Set</span>
#             <span style="color:#999;font-size:12px;">iceberg</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#4cc9f0" stroke-width="8"
#             stroke-dasharray="223.68 27.65"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">89%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Rows</td><td style="text-align:right;font-weight:600;">50,000</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">0</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">49,999</td></tr>
#           </table>
#         </div>
#       </div>
#     </div>

# %% [markdown]
# A small chunk of data is held in Kafka (£££) and the majority is held in Iceberg (pennies)

# %% [markdown]
# ## ALL IS ACCESSIBLE

# %%
For real-time analytics cases like:

"Is the latest transaction suspiciously higher than the average?"

# %%
q((''
'WITH latest_tx AS (          '
'   SELECT                    '
'        TransactionAmount    '
'    FROM isk.merged.transactions    '
'    ORDER BY TransactionTime DESC    '
'    LIMIT 1    '
'),    '
'avg_tx AS (    '
'    SELECT    '
'        AVG(TransactionAmount) AS avg_transaction_amount    '
'    FROM isk.merged.transactions    '
')    '
'SELECT    '
'    l.TransactionAmount AS latest_transaction_amount,    '
'    a.avg_transaction_amount    '
'FROM latest_tx l    '
'CROSS JOIN avg_tx a;'
''))
# Out:
#    latest_transaction_amount  avg_transaction_amount
# 0                    8961.96             5055.754931

# %% [markdown]
# Find the anomolies and fix before the impact is high

# %% [markdown]
# For cost saving in Kafka:
#
# "Backfill my flink job from Iceberg"

# %%
compose('exec', 'schema-registry', 'kafka-avro-console-consumer', '--topic', 'transactions', '--bootstrap-server', 'ksi:9192', '--from-beginning', '--property', 'schema.registry.url=http://schema-registry:8081', '--property', 'print.offset=true', '--max-messages', '50')
# Out:
# > docker compose --project-directory /home/thomaskwscott/Projects/breakstream/environment -f /home/thomaskwscott/Projects/breakstream/environment/docker-compose.yaml exec schema-registry kafka-avro-console-consumer --topic transactions --bootstrap-server ksi:9192 --from-beginning --property schema.registry.url=http://schema-registry:8081 --property print.offset=true --max-messages 50
# Offset:0	{"TransactionID":"cf754401-f354-3ef3-9a45-4092051d777e","AccountID":1090,"TransactionType":"Withdrawal","TransactionAmount":8557.01,"BranchID":116,"CustomerFlaggedFraud":false,"TransactionTime":1603452886000000}
# Offset:1	{"TransactionID":"cfbefef1-12f7-0ffc-0bd8-3e48874ae14e","AccountID":1182,"TransactionType":"Withdrawal","TransactionAmount":9513.81,"BranchID":112,"CustomerFlaggedFraud":false,"TransactionTime":1603453201540000}
# Offset:2	{"TransactionID":"5d169353-bc45-6b3c-96e6-358d9ee17e5d","AccountID":1051,"TransactionType":"Deposit","TransactionAmount":705.55,"BranchID":127,"CustomerFlaggedFraud":false,"TransactionTime":1603453517080000}
# Offset:3	{"TransactionID":"6296a49b-71cf-b32c-0345-cc67c24f4a70","AccountID":1345,"TransactionType":"Deposit","TransactionAmount":9409.88,"BranchID":126,"CustomerFlaggedFraud":false,"TransactionTime":1603453832620000}
# Offset:4	{"TransactionID":"23aa1ed0-d837-2d61-743e-e7a37b2a0f93","AccountID":1087,"TransactionType":"Deposit","TransactionAmount":8331.47,"BranchID":110,"CustomerFlaggedFraud":false,"TransactionTime":1603454148160000}
# Offset:5	{"TransactionID":"0e208cf9-779b-d6fd-eaf8-562b246d170e","AccountID":1264,"TransactionType":"Deposit","TransactionAmount":6934.48,"BranchID":113,"CustomerFlaggedFraud":false,"TransactionTime":1603454463700000}
# Offset:6	{"TransactionID":"d47a0c3a-5342-b698-da33-df75f46f6bd0","AccountID":1412,"TransactionType":"Deposit","TransactionAmount":4055.32,"BranchID":125,"CustomerFlaggedFraud":false,"TransactionTime":1603454779240000}
# Offset:7	{"TransactionID":"2f43a5c3-8e6a-6b83-1ba2-093548a84f28","AccountID":1197,"TransactionType":"Withdrawal","TransactionAmount":6733.77,"BranchID":126,"CustomerFlaggedFraud":false,"TransactionTime":1603455094780000}
# Offset:8	{"TransactionID":"31b5621e-1e1f-243c-4c31-738697dfb344","AccountID":1175,"TransactionType":"Withdrawal","TransactionAmount":4158.58,"BranchID":107,"CustomerFlaggedFraud":false,"TransactionTime":1603455410320000}
# Offset:9	{"TransactionID":"4d2b587f-1489-c585-d479-d5bc36572662","AccountID":1416,"TransactionType":"Deposit","TransactionAmount":6008.04,"BranchID":125,"CustomerFlaggedFraud":false,"TransactionTime":1603455725860000}
# Offset:10	{"TransactionID":"7f58c91e-8ada-cb37-155c-bc26d67d26d5","AccountID":1075,"TransactionType":"Withdrawal","TransactionAmount":8384.06,"BranchID":129,"CustomerFlaggedFraud":false,"TransactionTime":1603456041400000}
# Offset:11	{"TransactionID":"7fd48280-8bbb-c410-ddec-978f68c29cae","AccountID":1419,"TransactionType":"Deposit","TransactionAmount":1729.16,"BranchID":120,"CustomerFlaggedFraud":false,"TransactionTime":1603456356940000}
# Offset:12	{"TransactionID":"1f072387-a504-dfa8-41bc-83e9925729f4","AccountID":1226,"TransactionType":"Deposit","TransactionAmount":1089.75,"BranchID":111,"CustomerFlaggedFraud":false,"TransactionTime":1603456672480000}
# Offset:13	{"TransactionID":"450c8eb1-2f6c-aa52-ce84-02cbd4d338b4","AccountID":1014,"TransactionType":"Withdrawal","TransactionAmount":7322.94,"BranchID":101,"CustomerFlaggedFraud":false,"TransactionTime":1603456988020000}
# Offset:14	{"TransactionID":"d3e57c4f-9f2a-4d51-077e-97b9523a4194","AccountID":1004,"TransactionType":"Withdrawal","TransactionAmount":9012.06,"BranchID":110,"CustomerFlaggedFraud":false,"TransactionTime":1603457303560000}
# Offset:15	{"TransactionID":"22460eb2-f007-5405-fc15-827fa605b36c","AccountID":1135,"TransactionType":"Withdrawal","TransactionAmount":4742.61,"BranchID":104,"CustomerFlaggedFraud":false,"TransactionTime":1603457619100000}
# Offset:16	{"TransactionID":"cf36a204-b884-f227-a983-b4af577fc582","AccountID":1493,"TransactionType":"Deposit","TransactionAmount":6062.18,"BranchID":128,"CustomerFlaggedFraud":false,"TransactionTime":1603457934640000}
# Offset:17	{"TransactionID":"c3eefac8-ccb4-b6d9-3017-a7770b95bb0a","AccountID":1047,"TransactionType":"Withdrawal","TransactionAmount":7719.69,"BranchID":126,"CustomerFlaggedFraud":false,"TransactionTime":1603458250180000}
# Offset:18	{"TransactionID":"bad089e3-4238-bcf2-c85a-8c71d98be8fd","AccountID":1418,"TransactionType":"Withdrawal","TransactionAmount":2427.04,"BranchID":112,"CustomerFlaggedFraud":false,"TransactionTime":1603458565720000}
# Offset:19	{"TransactionID":"37e9bf33-8965-dc5b-1b38-c43275566e0e","AccountID":1048,"TransactionType":"Deposit","TransactionAmount":964.08,"BranchID":101,"CustomerFlaggedFraud":false,"TransactionTime":1603458881260000}
# Offset:20	{"TransactionID":"4dc6a8a2-601e-5078-edf6-29d86226c399","AccountID":1493,"TransactionType":"Withdrawal","TransactionAmount":8734.25,"BranchID":113,"CustomerFlaggedFraud":false,"TransactionTime":1603459196800000}
# Offset:21	{"TransactionID":"05f36fe8-e1f1-1783-d10f-c9f9ba027661","AccountID":1267,"TransactionType":"Withdrawal","TransactionAmount":8526.11,"BranchID":119,"CustomerFlaggedFraud":false,"TransactionTime":1603459512340000}
# Offset:22	{"TransactionID":"6df8e3db-3537-423a-d8ea-a70ca1a8be55","AccountID":1488,"TransactionType":"Deposit","TransactionAmount":3868.36,"BranchID":115,"CustomerFlaggedFraud":false,"TransactionTime":1603459827880000}
# Offset:23	{"TransactionID":"7882fdc6-e653-1e41-eeb7-b4e9a5307fc9","AccountID":1129,"TransactionType":"Deposit","TransactionAmount":9002.01,"BranchID":109,"CustomerFlaggedFraud":false,"TransactionTime":1603460143420000}
# Offset:24	{"TransactionID":"a7ed6a95-ad15-5871-b914-500c4e50cc20","AccountID":1191,"TransactionType":"Withdrawal","TransactionAmount":1643.39,"BranchID":112,"CustomerFlaggedFraud":false,"TransactionTime":1603460458960000}
# Offset:25	{"TransactionID":"2812f509-e4d5-c294-7a9f-bc883a44e190","AccountID":1321,"TransactionType":"Deposit","TransactionAmount":7018.64,"BranchID":102,"CustomerFlaggedFraud":false,"TransactionTime":1603460774500000}
# Offset:26	{"TransactionID":"146c7f59-e0bb-cc7f-2085-69d0aba87800","AccountID":1474,"TransactionType":"Withdrawal","TransactionAmount":5038.58,"BranchID":121,"CustomerFlaggedFraud":false,"TransactionTime":1603461090040000}
# Offset:27	{"TransactionID":"62df8cb7-d8e5-fe68-d5bc-8adcd3808297","AccountID":1017,"TransactionType":"Deposit","TransactionAmount":7571.78,"BranchID":112,"CustomerFlaggedFraud":false,"TransactionTime":1603461405580000}
# Offset:28	{"TransactionID":"f28a627b-77cb-2286-9546-14e9ca1040a9","AccountID":1416,"TransactionType":"Deposit","TransactionAmount":8428.47,"BranchID":120,"CustomerFlaggedFraud":false,"TransactionTime":1603461721120000}
# Offset:29	{"TransactionID":"44675ab3-7e11-ad34-2120-280f3ed2151b","AccountID":1412,"TransactionType":"Withdrawal","TransactionAmount":9436.8,"BranchID":100,"CustomerFlaggedFraud":false,"TransactionTime":1603462036660000}
# Offset:30	{"TransactionID":"74b4f7cf-d930-b4aa-867a-283fabb67e16","AccountID":1299,"TransactionType":"Deposit","TransactionAmount":5971.35,"BranchID":121,"CustomerFlaggedFraud":false,"TransactionTime":1603462352200000}
# Offset:31	{"TransactionID":"ae5d261e-9cfe-cd88-92b1-2126b4e92f8d","AccountID":1323,"TransactionType":"Deposit","TransactionAmount":1138.74,"BranchID":124,"CustomerFlaggedFraud":false,"TransactionTime":1603462667740000}
# Offset:32	{"TransactionID":"01f7422f-f0d4-a694-7dad-a0337e652a14","AccountID":1273,"TransactionType":"Withdrawal","TransactionAmount":2724.58,"BranchID":126,"CustomerFlaggedFraud":false,"TransactionTime":1603462983280000}
# Offset:33	{"TransactionID":"55ec8b89-e8f5-5ef8-903f-579396cd9d51","AccountID":1112,"TransactionType":"Withdrawal","TransactionAmount":1106.63,"BranchID":118,"CustomerFlaggedFraud":false,"TransactionTime":1603463298820000}
# Offset:34	{"TransactionID":"7db78480-9252-b165-a8cf-e3902e295906","AccountID":1147,"TransactionType":"Withdrawal","TransactionAmount":8258.16,"BranchID":129,"CustomerFlaggedFraud":false,"TransactionTime":1603463614360000}
# Offset:35	{"TransactionID":"2ab9e8b2-2e8e-ad6b-3e43-6d16a1f26cf5","AccountID":1136,"TransactionType":"Withdrawal","TransactionAmount":1538.32,"BranchID":119,"CustomerFlaggedFraud":false,"TransactionTime":1603463929900000}
# Offset:36	{"TransactionID":"0c6f19d9-99f2-7ad6-141b-69ed37c23066","AccountID":1281,"TransactionType":"Deposit","TransactionAmount":3719.83,"BranchID":103,"CustomerFlaggedFraud":false,"TransactionTime":1603464245440000}
# Offset:37	{"TransactionID":"6c729cef-06ee-aa5c-840d-dbfb6a4600e7","AccountID":1052,"TransactionType":"Deposit","TransactionAmount":8367.31,"BranchID":112,"CustomerFlaggedFraud":false,"TransactionTime":1603464560980000}
# Offset:38	{"TransactionID":"dc8a28e0-e337-169b-1c53-07558c2b5712","AccountID":1346,"TransactionType":"Deposit","TransactionAmount":3415.38,"BranchID":115,"CustomerFlaggedFraud":false,"TransactionTime":1603464876520000}
# Offset:39	{"TransactionID":"47ec21b5-179b-6b3a-7cd8-1a1d9a7accb9","AccountID":1270,"TransactionType":"Deposit","TransactionAmount":3520.16,"BranchID":113,"CustomerFlaggedFraud":false,"TransactionTime":1603465192060000}
# Offset:40	{"TransactionID":"834fe0b8-f041-ed80-f4f6-cbeec2d79a14","AccountID":1140,"TransactionType":"Withdrawal","TransactionAmount":4315.74,"BranchID":102,"CustomerFlaggedFraud":false,"TransactionTime":1603465507600000}
# Offset:41	{"TransactionID":"b52dbbfd-b80f-7966-6253-23e6d8175533","AccountID":1440,"TransactionType":"Deposit","TransactionAmount":8192.46,"BranchID":100,"CustomerFlaggedFraud":false,"TransactionTime":1603465823140000}
# Offset:42	{"TransactionID":"948effad-2377-b854-1103-992558cbb872","AccountID":1185,"TransactionType":"Withdrawal","TransactionAmount":703.46,"BranchID":117,"CustomerFlaggedFraud":false,"TransactionTime":1603466138680000}
# Offset:43	{"TransactionID":"1fe9b900-aaed-c019-df4f-69fa90746587","AccountID":1085,"TransactionType":"Withdrawal","TransactionAmount":3433.03,"BranchID":108,"CustomerFlaggedFraud":false,"TransactionTime":1603466454220000}
# Offset:44	{"TransactionID":"1b3e72ee-c52c-9316-83ca-440edead4f63","AccountID":1097,"TransactionType":"Deposit","TransactionAmount":5872.74,"BranchID":107,"CustomerFlaggedFraud":true,"TransactionTime":1603466769760000}
# Offset:45	{"TransactionID":"f775941c-0c48-8a1d-e6c3-e611291e171d","AccountID":1362,"TransactionType":"Withdrawal","TransactionAmount":7275.68,"BranchID":118,"CustomerFlaggedFraud":true,"TransactionTime":1603467085300000}
# Offset:46	{"TransactionID":"4127881c-4294-ac5e-9680-2063eb60f824","AccountID":1230,"TransactionType":"Withdrawal","TransactionAmount":1391.71,"BranchID":119,"CustomerFlaggedFraud":false,"TransactionTime":1603467400840000}
# Offset:47	{"TransactionID":"fa5c78ff-0209-bf10-9a7b-807e320a9561","AccountID":1011,"TransactionType":"Deposit","TransactionAmount":9003.96,"BranchID":106,"CustomerFlaggedFraud":false,"TransactionTime":1603467716380000}
# Offset:48	{"TransactionID":"08cebc71-fd87-6c11-c62b-d0c208f331d4","AccountID":1389,"TransactionType":"Deposit","TransactionAmount":7249.69,"BranchID":100,"CustomerFlaggedFraud":true,"TransactionTime":1603468031920000}
# Offset:49	{"TransactionID":"382e42d5-e2ea-a410-be80-d35f1b734f95","AccountID":1051,"TransactionType":"Withdrawal","TransactionAmount":9017.41,"BranchID":105,"CustomerFlaggedFraud":false,"TransactionTime":1603468347460000}
# Processed a total of 50 messages

# %% [markdown]
# # PART 3: SCHEMA EVOLUTION

# %% [markdown]
# ![image](images/slide7.png)

# %%
show_distribution()
# Out:
#     <div style="font-family:system-ui,sans-serif;border:1.5px solid #ff6b35;border-radius:8px;padding:16px;max-width:680px;">
#       <div style="margin-bottom:8px;">
#         <span style="color:#ff6b35;font-weight:700;font-size:15px;">Merged Set</span>
#         <span style="color:#222;font-size:15px;margin-left:16px;">Total Rows: <strong>50,034</strong></span>
#       </div>
#
#         <div style="display:flex;width:100%;height:32px;border-radius:4px;overflow:hidden;">
#           <div style="width:0.0%;background:#e63946;display:flex;align-items:center;justify-content:center;">
#
#           </div>
#           <div style="width:100.0%;background:#4cc9f0;display:flex;align-items:center;justify-content:center;">
#             <span style="color:#fff;font-size:12px;font-weight:600;pointer-events:none">Cold Set</span>
#           </div>
#         </div>
#       <div style="display:flex;gap:16px;margin-top:16px;">
#         <div style="flex:1;border:1.5px solid #e63946;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#e63946;font-weight:700;font-size:14px;">Hot Set</span>
#             <span style="color:#999;font-size:12px;">kafka</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e63946" stroke-width="8"
#             stroke-dasharray="0.00 251.33"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">0%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Messages</td><td style="text-align:right;font-weight:600;">23</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">50,000</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">50,022</td></tr>
#           </table>
#         </div>
#         <div style="flex:1;border:1.5px solid #4cc9f0;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#4cc9f0;font-weight:700;font-size:14px;">Cold Set</span>
#             <span style="color:#999;font-size:12px;">iceberg</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#4cc9f0" stroke-width="8"
#             stroke-dasharray="251.33 0.00"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">100%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Rows</td><td style="text-align:right;font-weight:600;">50,000</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">0</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">49,999</td></tr>
#           </table>
#         </div>
#       </div>
#     </div>

# %% [markdown]
# ## Pause traffic to examine schemas cleanly
#
# Now let's look at schema evolution — for example addition of a new field. Note that background data injection is stopped now — to surface messages easier and inject data with evolved schema.
#
# Let's describe the transactions table on the Hotset projection.

# %%
compose('down', 'shadowtraffic_background')
time.sleep(3)
# Out:
# > docker compose --project-directory /home/roman/code/breakstream/environment -f /home/roman/code/breakstream/environment/docker-compose.yaml down shadowtraffic_background
#  Container environment-shadowtraffic_background-1  Stopping
#  Container environment-shadowtraffic_background-1  Stopped
#  Container environment-shadowtraffic_background-1  Removing
#  Container environment-shadowtraffic_background-1  Removed
#  Network environment_default  Removing
#  Network environment_default  Resource is still in use

# %%
q("DESCRIBE isk.hotset.transactions")
# Out:
#                 col_name                       data_type comment
# 0          TransactionID                          string    None
# 1              AccountID                          bigint    None
# 2        TransactionType                          string    None
# 3      TransactionAmount                          double    None
# 4               BranchID                          bigint    None
# 5   CustomerFlaggedFraud                         boolean    None
# 6        TransactionTime                   timestamp_ntz    None
# 7        kafka_partition                             int    None
# 8           kafka_offset                          bigint    None
# 9        kafka_timestamp                   timestamp_ntz    None
# 10
# 11        # Partitioning
# 12                Part 0                 kafka_partition
# 13                Part 1  truncate(500000, kafka_offset)

# %% [markdown]
# And fetch last few rows as an example.
#
# Now — let's produce some new messages with additional field FraudRiskScore.

# %%
q("SELECT * FROM isk.hotset.transactions ORDER BY kafka_offset DESC LIMIT 10")
# Out:
#                           TransactionID  AccountID TransactionType  \
# 0  c53920a4-96d9-f06a-fdb9-e904204a67bc       1144      Withdrawal
# 1  5f03aed5-9841-9feb-5208-55b2d099a2df       1299         Deposit
# 2  04ed17fb-ba92-4ade-3a62-4c49e6ace728       1428         Deposit
# 3  7cddda5b-534f-74f1-26c5-4388f8b729ad       1267         Deposit
# 4  bcea6cc8-7e5e-de13-3c2a-079c5a3baf08       1180      Withdrawal
# 5  4e2b2383-9cc5-26ae-7c24-cf4828c7cb8c       1019         Deposit
# 6  399ac209-a640-4290-0db4-7bdd8d87850a       1042         Deposit
# 7  d2e1d607-82a4-31c2-dc1c-7739e42a4f41       1369         Deposit
# 8  f2b90d54-6b6e-023c-57b9-79cfe2ca9959       1391      Withdrawal
# 9  faeaf9af-e8f0-5f55-b15d-e87d7ca4dfef       1432      Withdrawal
#
#    TransactionAmount  BranchID  CustomerFlaggedFraud         TransactionTime  \
# 0            8079.26       103                  True 2025-10-23 12:35:07.312
# 1            9118.69       110                 False 2025-10-23 12:35:06.979
# 2            1561.95       121                  True 2025-10-23 12:35:06.646
# 3            8055.15       121                  True 2025-10-23 12:35:06.313
# 4            2245.16       121                 False 2025-10-23 12:35:05.980
# 5            8980.00       113                  True 2025-10-23 12:35:05.647
# 6            7940.68       115                  True 2025-10-23 12:35:05.314
# 7             712.85       103                  True 2025-10-23 12:35:04.981
# 8            8421.78       103                  True 2025-10-23 12:35:04.648
# 9            7077.28       121                  True 2025-10-23 12:35:04.315
#
#    kafka_partition  kafka_offset         kafka_timestamp
# 0                0         50064 2026-05-08 09:20:09.950
# 1                0         50063 2026-05-08 09:20:09.617
# 2                0         50062 2026-05-08 09:20:09.283
# 3                0         50061 2026-05-08 09:20:08.950
# 4                0         50060 2026-05-08 09:20:08.617
# 5                0         50059 2026-05-08 09:20:08.283
# 6                0         50058 2026-05-08 09:20:07.950
# 7                0         50057 2026-05-08 09:20:07.617
# 8                0         50056 2026-05-08 09:20:07.283
# 9                0         50055 2026-05-08 09:20:06.950

# %% [markdown]
# ## Inject events with evolved schema
#
# We now run a one-shot setup that adds a new column `FraudRiskScore` to the transactions topic, then start a new background generator that emits events with this evolved schema.

# %%
compose('up', '--wait', 'shadowtraffic_setup_evolved')
# Out:
# > docker compose --project-directory /home/roman/code/breakstream/environment -f /home/roman/code/breakstream/environment/docker-compose.yaml up --wait shadowtraffic_setup_evolved
#  Container environment-zookeeper1-1  Running
#  Container environment-kafka1-1  Running
#  Container schema-registry  Running
#  Container environment-shadowtraffic_setup_evolved-1  Recreate
#  Container environment-shadowtraffic_setup_evolved-1  Recreated
#  Container schema-registry  Waiting
#  Container schema-registry  Healthy
#  Container environment-shadowtraffic_setup_evolved-1  Starting
#  Container environment-shadowtraffic_setup_evolved-1  Started
#  Container environment-kafka1-1  Waiting
#  Container schema-registry  Waiting
#  Container environment-zookeeper1-1  Waiting
#  Container environment-shadowtraffic_setup_evolved-1  Waiting
#  Container environment-zookeeper1-1  Healthy
#  Container environment-shadowtraffic_setup_evolved-1  Healthy
#  Container environment-kafka1-1  Healthy
#  Container schema-registry  Healthy

# %%
compose('up', '-d', 'shadowtraffic_background_evolved')
time.sleep(8)

# %% [markdown]
# Now that new data is coming into the topic with evolved schema (FraudRiskScore optional field added) — let's describe the table again.

# %%
q("DESCRIBE isk.hotset.transactions")
# Out:
#                 col_name                       data_type comment
# 0          TransactionID                          string    None
# 1              AccountID                          bigint    None
# 2        TransactionType                          string    None
# 3      TransactionAmount                          double    None
# 4               BranchID                          bigint    None
# 5   CustomerFlaggedFraud                         boolean    None
# 6        TransactionTime                   timestamp_ntz    None
# 7         FraudRiskScore                          double    None
# 8        kafka_partition                             int    None
# 9           kafka_offset                          bigint    None
# 10       kafka_timestamp                   timestamp_ntz    None
# 11
# 12        # Partitioning
# 13                Part 0                 kafka_partition
# 14                Part 1  truncate(500000, kafka_offset)

# %% [markdown]
# And check the latest events added to it. Note the newest events have FraudRiskScore populated — while older ones are rendered with null (events pre-schema change).
#
# Now we can restart ongoing data injection — but using evolved schema.

# %%
q("SELECT * FROM isk.hotset.transactions ORDER BY kafka_offset DESC LIMIT 15")
# Out:
#                            TransactionID  AccountID TransactionType  \
# 0   4a9f8c55-326f-cb86-98d3-f1c22ff0e9c5       1103         Deposit
# 1   0b95bb0a-1a44-bf5e-c059-fd71c0d35d52       1369      Withdrawal
# 2   08e67c47-e492-cc54-3b2b-a5bd42231b49       1470         Deposit
# 3   6d9da8cd-0bb4-8fdc-09fd-f42d93e8e164       1326      Withdrawal
# 4   8285ef7f-6d0a-91f5-ced8-649a915870b2       1359      Withdrawal
# 5   7a1f9f71-bde0-1e0b-9a70-9b7121919a08       1097         Deposit
# 6   72269b9b-7f01-7da7-e83b-d1f3a15fd053       1398      Withdrawal
# 7   1e5e7741-c60f-670a-a418-84ee850c7d70       1388         Deposit
# 8   c226d0d1-c673-2c2f-ef5a-3eaf2fb8cd77       1457         Deposit
# 9   3eac5560-8587-0842-ad8a-3765d9435c1d       1106      Withdrawal
# 10  169fd4f2-d811-2c8b-188d-a92879bb9246       1141      Withdrawal
# 11  7733789d-872d-01b9-7a71-e24d1a19a4db       1069         Deposit
# 12  79e02319-c4bd-75f3-a084-ad85b56550f6       1294         Deposit
# 13  bb755f20-669b-fa65-31b5-621e1e1f243c       1204         Deposit
# 14  c8d676dd-7ca5-c2d4-e5ac-7581e4f4a813       1401         Deposit
#
#     TransactionAmount  BranchID  CustomerFlaggedFraud         TransactionTime  \
# 0             7357.29       121                  True 2025-10-23 12:34:57.322
# 1             8674.69       121                  True 2025-10-23 12:34:56.989
# 2             8916.24       117                 False 2025-10-23 12:34:56.656
# 3             6282.27       103                 False 2025-10-23 12:34:56.323
# 4             8182.55       126                 False 2025-10-23 12:34:55.990
# 5             5638.12       126                 False 2025-10-23 12:34:55.657
# 6             3356.88       102                  True 2025-10-23 12:34:55.324
# 7             5993.47       123                  True 2025-10-23 12:34:54.991
# 8             6086.54       106                  True 2025-10-23 12:34:54.658
# 9             1797.43       125                  True 2025-10-23 12:34:54.325
# 10            1208.19       121                  True 2025-10-23 12:34:53.992
# 11            7499.16       116                  True 2025-10-23 12:34:53.659
# 12            5072.96       121                 False 2025-10-23 12:34:53.326
# 13            2479.15       101                 False 2025-10-23 12:34:52.993
# 14            4576.32       121                  True 2025-10-23 12:34:52.660
#
#     FraudRiskScore  kafka_partition  kafka_offset         kafka_timestamp
# 0             6.30                0         50144 2026-05-08 09:21:05.733
# 1             1.38                0         50143 2026-05-08 09:21:05.400
# 2             3.41                0         50142 2026-05-08 09:21:05.066
# 3             6.79                0         50141 2026-05-08 09:21:04.732
# 4             1.41                0         50140 2026-05-08 09:21:04.399
# 5             8.53                0         50139 2026-05-08 09:21:04.066
# 6             7.14                0         50138 2026-05-08 09:21:03.732
# 7             4.91                0         50137 2026-05-08 09:21:03.399
# 8             7.62                0         50136 2026-05-08 09:21:03.066
# 9             6.08                0         50135 2026-05-08 09:21:02.732
# 10            2.21                0         50134 2026-05-08 09:21:02.399
# 11            2.65                0         50133 2026-05-08 09:21:02.066
# 12            4.92                0         50132 2026-05-08 09:21:01.732
# 13            1.91                0         50131 2026-05-08 09:21:01.399
# 14            1.47                0         50130 2026-05-08 09:21:01.066

# %% [markdown]
# Right now our data is spread across Kafka and Iceberg. The Iceberg share (coldset) remains static in size but the Kafka share (hotset) is continuously growing.
#
# Unbounded growth like this is often not optimal. Streambased allows you to use your Iceberg engine (in this case Spark) to easily transfer data from hotset to coldset.
#
# Let's start by looking at the current data population in each set for the transactions table.

# %%
show_distribution()
# Out:
#     <div style="font-family:system-ui,sans-serif;border:1.5px solid #ff6b35;border-radius:8px;padding:16px;max-width:680px;">
#       <div style="margin-bottom:8px;">
#         <span style="color:#ff6b35;font-weight:700;font-size:15px;">Merged Set</span>
#         <span style="color:#222;font-size:15px;margin-left:16px;">Total Rows: <strong>50,174</strong></span>
#       </div>
#
#         <div style="display:flex;width:100%;height:32px;border-radius:4px;overflow:hidden;">
#           <div style="width:0.0%;background:#e63946;display:flex;align-items:center;justify-content:center;">
#
#           </div>
#           <div style="width:100.0%;background:#4cc9f0;display:flex;align-items:center;justify-content:center;">
#             <span style="color:#fff;font-size:12px;font-weight:600;pointer-events:none">Cold Set</span>
#           </div>
#         </div>
#       <div style="display:flex;gap:16px;margin-top:16px;">
#         <div style="flex:1;border:1.5px solid #e63946;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#e63946;font-weight:700;font-size:14px;">Hot Set</span>
#             <span style="color:#999;font-size:12px;">kafka</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e63946" stroke-width="8"
#             stroke-dasharray="0.00 251.33"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">0%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Messages</td><td style="text-align:right;font-weight:600;">145</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">50,000</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">50,144</td></tr>
#           </table>
#         </div>
#         <div style="flex:1;border:1.5px solid #4cc9f0;border-radius:6px;padding:12px;">
#           <div style="display:flex;justify-content:space-between;align-items:baseline;margin-bottom:8px;">
#             <span style="color:#4cc9f0;font-weight:700;font-size:14px;">Cold Set</span>
#             <span style="color:#999;font-size:12px;">iceberg</span>
#           </div>
#           <div style="display:flex;justify-content:center;margin:8px 0;">
#
#         <svg width="100" height="100" viewBox="0 0 100 100">
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#e9ecef" stroke-width="8"/>
#           <circle cx="50" cy="50" r="40" fill="none" stroke="#4cc9f0" stroke-width="8"
#             stroke-dasharray="251.33 0.00"
#             stroke-linecap="round"
#             transform="rotate(-90 50 50)"/>
#           <text x="50" y="50" text-anchor="middle" dominant-baseline="central"
#             style="font-size:16px;font-weight:700;fill:#222;">100%</text>
#         </svg>
#           </div>
#           <table style="width:100%;font-size:13px;border-collapse:collapse;">
#             <tr><td style="color:#555;">Total Rows</td><td style="text-align:right;font-weight:600;">50,000</td></tr>
#             <tr><td style="color:#555;">Earliest Offset</td><td style="text-align:right;">0</td></tr>
#             <tr><td style="color:#555;">Latest Offset</td><td style="text-align:right;">49,999</td></tr>
#           </table>
#         </div>
#       </div>
#     </div>

# %% [markdown]
# Moving data from Kafka to Iceberg is a simple `INSERT INTO ... SELECT FROM` statement with Streambased — we simply select from the hotset into the coldset.
#
# Transferring data in this way has the following advantages:
#
# * Transfer from hotset to coldset is not a pre-requisite for data access
# * It can be scheduled during low resource usage periods.
# * Data can be accumulated in Kafka until it is efficient to transfer it (no small files).
# * The transfer process is atomic and involves no downtime.
#
# But first we need to add the new column to the coldset — reflecting the Kafka schema evolution.

# %%
q("ALTER TABLE direct.coldset.transactions ADD COLUMN FraudRiskScore double AFTER TransactionTime")
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
q("DESCRIBE direct.coldset.transactions")
# Out:
#                 col_name                     data_type comment
# 0          TransactionID                        string    None
# 1              AccountID                        bigint    None
# 2        TransactionType                        string    None
# 3      TransactionAmount                        double    None
# 4               BranchID                        bigint    None
# 5   CustomerFlaggedFraud                       boolean    None
# 6        TransactionTime                 timestamp_ntz    None
# 7         FraudRiskScore                        double    None
# 8        kafka_partition                           int    None
# 9           kafka_offset                        bigint    None
# 10       kafka_timestamp                 timestamp_ntz    None
# 11
# 12        # Partitioning
# 13                Part 0               kafka_partition
# 14                Part 1  truncate(1000, kafka_offset)

# %% [markdown]
# And finally move the data using the `INSERT INTO ... SELECT FROM` statement.

# %%
q("INSERT INTO direct.coldset.transactions SELECT * FROM isk.hotset.transactions")

# %% [markdown]
# After transfer the coldset population has increased. Streambased will now serve a larger share of the merged dataset from the coldset.
#
# Why hasn't the hotset population decreased?
#
# Streambased will not explicitly delete data from Kafka. Kafka deletion is handled by the topic retention policy as usual.
#
# The merged set now contains all of the coldset + the section of hotset that has not yet been transferred to the coldset, as you can see below.

# %%
show_distribution()

# %% [markdown]
# The hot/cold lifecycle is complete. Data originated in Kafka (hotset), was seamlessly unified with existing Iceberg data in the merged view, and has now been durably archived to the coldset — all without any downtime or schema lock-in.
#
# From here you can explore further: run time-travel queries against the coldset snapshots, inspect Kafka lag independently of query latency, or try the advanced demos covering KSI-accelerated lookups and Slipstream change feeds.
